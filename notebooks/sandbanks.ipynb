# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from PIL import Image
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load the data
image = Image.open("/home/jouell/code/jouell3/plant_detect/data/images/0.jpg")
